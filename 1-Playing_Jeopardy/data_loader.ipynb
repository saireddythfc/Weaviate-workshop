# %%
#Loading environment variables

import os

WEAVIATE_CLUSTER_URL = os.getenv("WEAVIATE_CLUSTER_URL")
WEAVIATE_API_KEY = os.getenv("WEAVIATE_API_KEY")

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
COHERE_API_KEY = os.getenv("COHERE_API_KEY")

# %% [markdown]
# ## Connecting to Weaviate client
#
# * Create a sandbox cluster on [Weaviate Cloud Services](https://console.weaviate.cloud/dashboard) and get the cluster_url and api key for authentication.
# * Create OpenAI/Cohere API Keys to include them into your headers.

# %%
import weaviate, os

#Connecting to WCS instance

client = weaviate.connect_to_wcs(
    cluster_url=WEAVIATE_CLUSTER_URL,
    auth_credentials=weaviate.auth.AuthApiKey(WEAVIATE_API_KEY),
    headers={
        "X-OpenAI-Api-Key": OPENAI_API_KEY,
        "X-Cohere-Api-Key": COHERE_API_KEY,
    }
)

client.is_ready()
# Out:
# True

# %% [markdown]
# ## Create a collection

# %%
import weaviate.classes.config as wc

if client.collections.exists("Questions"):
    client.collections.delete("Questions")

client.collections.create(
    name="Questions",
    vectorizer_config=wc.Configure.Vectorizer.text2vec_openai()
)

# %% [markdown]
# ## Import Data

# %% [markdown]
# #### Sample Data

# %%
import json

data_10 = json.load(open("./data/jeopardy_tiny.json"))
print(json.dumps(data_10, indent=2))
# Out:
# [
#   {
#     "Category": "SCIENCE",
#     "Question": "This organ removes excess glucose from the blood & stores it as glycogen",
#     "Answer": "Liver"
#   },
#   {
#     "Category": "ANIMALS",
#     "Question": "It's the only living mammal in the order Proboseidea",
#     "Answer": "Elephant"
#   },
#   {
#     "Category": "ANIMALS",
#     "Question": "The gavial looks very much like a crocodile except for this bodily feature",
#     "Answer": "the nose or snout"
#   },
#   {
#     "Category": "ANIMALS",
#     "Question": "Weighing around a ton, the eland is the largest species of this animal in Africa",
#     "Answer": "Antelope"
#   },
#   {
#     "Category": "ANIMALS",
#     "Question": "Heaviest of all poisonous snakes is this North American rattlesnake",
#     "Answer": "the diamondback rattler"
#   },
#   {
#     "Category": "SCIENCE",
#     "Question": "2000 news: the Gunnison sage grouse isn't just another northern sage grouse, but a new one of this classification",
#     "Answer": "species"
#   },
#   {
#     "Category": "SCIENCE",
#     "Question": "A metal that is ductile can be pulled into this while cold & under pressure",
#     "Answer": "wire"
#   },
#   {
#     "Category": "SCIENCE",
#     "Question": "In 1953 Watson & Crick built a model of the molecular structure of this, the gene-carrying substance",
#     "Answer": "DNA"
#   },
#   {
#     "Category": "SCIENCE",
#     "Question": "Changes in the tropospheric layer of this are what gives us weather",
#     "Answer": "the atmosphere"
#   },
#   {
#     "Category": "SCIENCE",
#     "Question": "In 70-degree air, a plane traveling at about 1,130 feet per second breaks it",
#     "Answer": "Sound barrier"
#   }
# ]
# /var/folders/3v/_jgc177x2ln06306pq8qlcqc0000gn/T/ipykernel_16934/246799287.py:3: ResourceWarning: unclosed file <_io.TextIOWrapper name='./data/jeopardy_tiny.json' mode='r' encoding='UTF-8'>
#   data_10 = json.load(open("./data/jeopardy_tiny.json"))
# ResourceWarning: Enable tracemalloc to get the object allocation traceback

# %% [markdown]
# #### Insert Many

# %%
collection = client.collections.get("Questions")
collection.data.insert_many(data_10)
# Out:
# BatchObjectReturn(all_responses=[UUID('ea018278-0d1c-4bdc-b4ef-acc2fd6bda40'), UUID('8edaa000-a548-4a5e-86c8-3c05aedec1c8'), UUID('7337ee25-a090-4c53-9931-0bd86ea967c2'), UUID('0bbaf7ab-4106-49ee-be34-193f4cb25d41'), UUID('55ac5456-3580-407a-8e73-14513056d853'), UUID('8f1c5bd4-d479-4d4f-ad28-fbce6c1a899a'), UUID('d1ca1c44-0444-41c3-ad79-8ca163bcad7d'), UUID('9ea0af91-4281-4542-aafe-769caa5ea081'), UUID('047010e2-de6d-4429-9183-97cf5582f9af'), UUID('94f26695-794c-4e16-a9b1-f60e6cb7880e')], elapsed_seconds=1.4283568859100342, errors={}, uuids={0: UUID('ea018278-0d1c-4bdc-b4ef-acc2fd6bda40'), 1: UUID('8edaa000-a548-4a5e-86c8-3c05aedec1c8'), 2: UUID('7337ee25-a090-4c53-9931-0bd86ea967c2'), 3: UUID('0bbaf7ab-4106-49ee-be34-193f4cb25d41'), 4: UUID('55ac5456-3580-407a-8e73-14513056d853'), 5: UUID('8f1c5bd4-d479-4d4f-ad28-fbce6c1a899a'), 6: UUID('d1ca1c44-0444-41c3-ad79-8ca163bcad7d'), 7: UUID('9ea0af91-4281-4542-aafe-769caa5ea081'), 8: UUID('047010e2-de6d-4429-9183-97cf5582f9af'), 9: UUID('94f26695-794c-4e16-a9b1-f60e6cb7880e')}, has_errors=False)

# %% [markdown]
# #### Data preview

# %%
#Fetch data from vector store
response = collection.query.fetch_objects(limit=5)

for item in response.objects:
    print(item.properties)
# Out:
# {'answer': 'the atmosphere', 'question': 'Changes in the tropospheric layer of this are what gives us weather', 'category': 'SCIENCE'}
# {'answer': 'Antelope', 'question': 'Weighing around a ton, the eland is the largest species of this animal in Africa', 'category': 'ANIMALS'}
# {'answer': 'the diamondback rattler', 'question': 'Heaviest of all poisonous snakes is this North American rattlesnake', 'category': 'ANIMALS'}
# {'answer': 'the nose or snout', 'question': 'The gavial looks very much like a crocodile except for this bodily feature', 'category': 'ANIMALS'}
# {'answer': 'Elephant', 'question': "It's the only living mammal in the order Proboseidea", 'category': 'ANIMALS'}

# %%
#Fetch data from vector store alongwith its vector
response = collection.query.fetch_objects(limit=5, include_vector=True)

for item in response.objects:
    print(item.properties)
    print(item.vector)
    #print(len(item.vector["default"])) ##1536 for OpenAI
# Out:
# {'answer': 'the atmosphere', 'question': 'Changes in the tropospheric layer of this are what gives us weather', 'category': 'SCIENCE'}
# {'default': [0.019746119156479836, 0.015562730841338634, 0.002706704894080758, -0.04217592254281044, 0.0045418706722557545, 0.015273313969373703, -0.0017677446594461799, -0.015194381587207317, -0.013549968600273132, -0.024955620989203453, -0.00842597521841526, 0.005512074567377567, -0.023995283991098404, 0.005748869851231575, 0.009294225834310055, 0.0021212936844676733, 0.023613780736923218, 0.022324560210108757, -0.019140975549817085, -0.012273903004825115, -0.011346453800797462, 0.0009751372854225338, -0.001521904836408794, 0.010780775919556618, 0.017614958807826042, -0.01686510629951954, 0.0314675010740757, -0.040307868272066116, -0.011747690849006176, 0.014326131902635098, 0.015694282948970795, 0.0009619820048101246, -0.03428273648023
# %% [markdown]
# ## Creating a custom collection with LLM and Generative Model

# %%
#Creating custom collection using OpenAI vectorizer and Generative model with required properties

# Skip vectorization is usually applied on similar/repeating fields.
# There is a possibility that one object can be stored as multiple vectors capturing different information. (screen in "name", fridge screen category)

if client.collections.exists("Questions"):
    client.collections.delete("Questions")

client.collections.create(
    name="Questions",
    vectorizer_config=wc.Configure.Vectorizer.text2vec_openai(),
    generative_config=wc.Configure.Generative.openai("gpt-4"),
    properties=[
        wc.Property(name="Question", data_type=wc.DataType.TEXT),
        wc.Property(name="Round", data_type=wc.DataType.TEXT, skip_vectorization=True),
        wc.Property(name="Category", data_type=wc.DataType.TEXT, skip_vectorization=True),
        wc.Property(name="Answer", data_type=wc.DataType.TEXT)
    ]
)

# %% [markdown]
# #### Import data - 1k objects

# %%
data_1k = json.load(open("./data/jeopardy_1k.json"))

print(json.dumps(data_1k, indent=2))
# Out:
# [
#   {
#     "AirDate": "2006-11-08T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 800,
#     "Category": "AMERICAN HISTORY",
#     "Question": "Abraham Lincoln died across the street from this theatre on April 15, 1865",
#     "Answer": "Ford's Theatre (the Ford Theatre accepted)"
#   },
#   {
#     "AirDate": "2005-11-18T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 200,
#     "Category": "RHYME TIME",
#     "Question": "Any pigment on the wall so faded you can barely see it",
#     "Answer": "faint paint"
#   },
#   {
#     "AirDate": "1987-06-23T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 600,
#     "Category": "AMERICAN HISTORY",
#     "Question": "After the original 13, this was the 1st state admitted to the union",
#     "Answer": "Vermont"
#   },
#   {
#     "AirDate": "2011-01-13T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 400,
#     "Category": "TRANSPORTATION",
#     "Question": "In 1922 Warren Harding said that this \"gauges the speed of our present-day life. It long ago ran down simple living\"",
#     "Answer": "the automobile"
#   },
#   {
#     "AirDate": "2001-12-03T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 800,
#     "Category": "AMERICAN HISTORY",
#     "Question": "On Jan. 19, 1977 President Ford pardoned this woman who'd been convicted of treason in World War II",
#     "Answer": "Tokyo Rose"
#   },
#   {
#     "AirDate": "1984-09-10T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 400,
#     "Category": "ANIMALS",
#     "Question": "Close relative of the pig, though its name means \"river horse\"",
#     "Answer": "the hippopotamus"
#   },
#   {
#     "AirDate": "1988-07-05T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 400,
#     "Category": "FOOD",
#     "Question": "When it's young & tender, this gourd used in the bathtub can be eaten like a squash",
#     "Answer": "a luffa"
#   },
#   {
#     "AirDate": "1997-05-16T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 400,
#     "Category": "WORLD HISTORY",
#     "Question": "In 1517 Cordova became the first Spaniard to reach Mexico when he landed on this east coast peninsula",
#     "Answer": "Yucatan Peninsula"
#   },
#   {
#     "AirDate": "2004-10-04T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 400,
#     "Category": "SCIENCE & NATURE",
#     "Question": "Like an escargot, the abalone is an edible one of these gastropods",
#     "Answer": "a snail"
#   },
#   {
#     "AirDate": "1985-10-02T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 100,
#     "Category": "ANIMALS",
#     "Question": "Even in the wild, this largest of apes takes a midday nap",
#     "Answer": "gorilla"
#   },
#   {
#     "AirDate": "1996-01-11T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 800,
#     "Category": "ART",
#     "Question": "You can see his \"Majas on a Balcony\" at the Metropolitan Museum of Art",
#     "Answer": "Francisco Goya"
#   },
#   {
#     "AirDate": "1992-11-10T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 400,
#     "Category": "ART",
#     "Question": "This kind of painting on plaster was a speciality of 15th c. artist Piero della Francesca",
#     "Answer": "Fresco"
#   },
#   {
#     "AirDate": "1999-01-25T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 600,
#     "Category": "POTPOURRI",
#     "Question": "In this sport a long basket called a cesta is worn on one hand",
#     "Answer": "jai alai"
#   },
#   {
#     "AirDate": "2000-07-17T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 300,
#     "Category": "PEOPLE",
#     "Question": "In 1939 this famous architect polished off his Johnson Wax Building in Racine, Wisconsin",
#     "Answer": "Frank Lloyd Wright"
#   },
#   {
#     "AirDate": "1998-10-01T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 100,
#     "Category": "POTPOURRI",
#     "Question": "Country in which you'd find the Book of Kells",
#     "Answer": "Ireland"
#   },
#   {
#     "AirDate": "1994-05-23T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 500,
#     "Category": "THE BIBLE",
#     "Question": "The single longest of Paul's epistles is addressed to these people",
#     "Answer": "the Romans"
#   },
#   {
#     "AirDate": "2003-06-18T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 400,
#     "Category": "BEFORE & AFTER",
#     "Question": "The world's oldest teenager who's a chocolate-coated candy with a peanut butter center",
#     "Answer": "Dick Clark Bar"
#   },
#   {
#     "AirDate": "2004-01-06T00:00:00+00:00",
#     "Round": "Final Jeopardy!",
#     "Points": 0,
#     "Category": "ANIMALS",
#     "Question": "Camelus, the genus name of camels, is also the species name of these birds",
#     "Answer": "ostriches"
#   },
#   {
#     "AirDate": "1999-04-22T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 200,
#     "Category": "BEFORE & AFTER",
#     "Question": "\"Home of the Whopper\" that fathered Cordelia, Regan & Goneril",
#     "Answer": "Burger King Lear"
#   },
#   {
#     "AirDate": "1990-02-19T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 400,
#     "Category": "OPERA",
#     "Question": "Operas based on this Norwegian's plays include \"The Feast at Solhaug\" & \"Peer Gynt\"",
#     "Answer": "Henrik Ibsen"
#   },
#   {
#     "AirDate": "2000-07-05T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 500,
#     "Category": "THE BIBLE",
#     "Question": "Both the gospel of Luke & this book are addressed to someone named Theophilus",
#     "Answer": "Acts of the Apostles"
#   },
#   {
#     "AirDate": "1990-05-01T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 500,
#     "Category": "BODIES OF WATER",
#     "Question": "Once part of the Gulf of California, it's now the largest natural lake entirely within the state",
#     "Answer": "Salton Sea"
#   },
#   {
#     "AirDate": "2004-10-06T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 2000,
#     "Category": "WORLD HISTORY",
#     "Question": "In 1530 a statement of faith, or \"confession\", was issued from this German city named for a Roman Emperor",
#     "Answer": "Augsburg"
#   },
#   {
#     "AirDate": "1996-11-12T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 400,
#     "Category": "ART",
#     "Question": "This \"Mona Lisa\" artist is noted for the sfumato, or smoky, quality of his paintings",
#     "Answer": "Leonardo da Vinci"
#   },
#   {
#     "AirDate": "1996-12-17T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 500,
#     "Category": "MUSEUMS",
#     "Question": "This eastern Minnesota city is home to the Lake Superior Museum of Transportation",
#     "Answer": "Duluth"
#   },
#   {
#     "AirDate": "1988-11-16T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 1000,
#     "Category": "HISTORY",
#     "Question": "An eighteenth-century war was named for this part of Robert Jenkins' body, reputedly cut off by Spaniards",
#     "Answer": "Ear"
#   },
#   {
#     "AirDate": "1999-10-06T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 300,
#     "Category": "THE BIBLE",
#     "Question": "In the Old Testament, Othniel, Ehud, Shamgar & others collectively, but not Judy",
#     "Answer": "Judges"
#   },
#   {
#     "AirDate": "1997-02-03T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 400,
#     "Category": "COLLEGES & UNIVERSITIES",
#     "Question": "This university's Santa Cruz campus is the headquarters of the Lick Observatory",
#     "Answer": "University of California"
#   },
#   {
#     "AirDate": "1991-11-08T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 500,
#     "Category": "U.S. GEOGRAPHY",
#     "Question": "This state borders two Canadian provinces: Manitoba & Saskatchewan",
#     "Answer": "North Dakota"
#   },
#   {
#     "AirDate": "1992-05-21T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 500,
#     "Category": "TELEVISION",
#     "Question": "In \"The Dick Van Dyke Show\", it was the series for which Rob Petrie was head writer",
#     "Answer": "The Alan Brady Show"
#   },
#   {
#     "AirDate": "2000-02-24T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 500,
#     "Category": "SCIENCE & NATURE",
#     "Question": "The adult human brain is made up of more than 10 billion of these nerve cells",
#     "Answer": "Neurons"
#   },
#   {
#     "AirDate": "2008-09-29T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 600,
#     "Category": "STUPID ANSWERS",
#     "Question": "The government admin. was created in 1971 to ensure occupational health & safety standards",
#     "Answer": "OSHA (Occupational Safety and Health Administration)"
#   },
#   {
#     "AirDate": "2008-06-02T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 1600,
#     "Category": "ART",
#     "Question": "Roger Fry of the Met coined this term for the works of artists like Cezanne & Gauguin",
#     "Answer": "Postimpressionist"
#   },
#   {
#     "AirDate": "1999-05-10T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 500,
#     "Category": "U.S. CITIES",
#     "Question": "The site of the World's Fair in 1962, it's flanked on the west by Puget Sound & on the east by Lake Washington",
#     "Answer": "Seattle"
#   },
#   {
#     "AirDate": "2007-09-26T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 600,
#     "Category": "BUSINESS & INDUSTRY",
#     "Question": "Legend has it that the design of this company's Monsieur Bibendum logo was inspired by a pile of rubber tires",
#     "Answer": "Michelin"
#   },
#   {
#     "AirDate": "2008-07-01T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 2000,
#     "Category": "BOOKS & AUTHORS",
#     "Question": "This James Joyce work is a dream sequence in the minds of the Earwicker family",
#     "Answer": "Finnegans Wake"
#   },
#   {
#     "AirDate": "2005-10-14T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 200,
#     "Category": "BALLET",
#     "Question": "The ballet \"Les patineurs\" focuses on this athletic pastime, with the dancers gliding by in wintry setting",
#     "Answer": "ice skating"
#   },
#   {
#     "AirDate": "1989-11-06T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 600,
#     "Category": "SHAKESPEARE",
#     "Question": "Cordelia's 1st words in this play are \"What shall Cordelia speak?  Love, and be silent\"",
#     "Answer": "\"King Lear\""
#   },
#   {
#     "AirDate": "2008-01-03T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 800,
#     "Category": "LITERATURE",
#     "Question": "Washington Irving based this character on his friend Jesse Merwin, a schoolteacher",
#     "Answer": "Ichabod Crane"
#   },
#   {
#     "AirDate": "1997-02-17T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 100,
#     "Category": "TELEVISION",
#     "Question": "This comedian's TV roles have included Alexander Scott, Dr. Cliff Huxtable & Hilton Lucas",
#     "Answer": "Bill Cosby"
#   },
#   {
#     "AirDate": "2008-09-15T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 2000,
#     "Category": "SPORTS",
#     "Question": "The Royal Report is the official e-newsletter of this hockey team",
#     "Answer": "the L.A. Kings"
#   },
#   {
#     "AirDate": "1996-10-02T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 200,
#     "Category": "BODIES OF WATER",
#     "Question": "Several structures called London Bridge have spanned this river, the latest completed in 1972",
#     "Answer": "the Thames"
#   },
#   {
#     "AirDate": "1990-11-08T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 400,
#     "Category": "FOOD",
#     "Question": "Pumpernickel bread is made primarily of this grain",
#     "Answer": "rye"
#   },
#   {
#     "AirDate": "2006-05-29T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 1200,
#     "Category": "BEFORE & AFTER",
#     "Question": "Presidential assassin who won acclaim for the novels \"The Magnificent Ambersons\" & \"Alice Adams\"",
#     "Answer": "John Wilkes Booth Tarkington"
#   },
#   {
#     "AirDate": "1997-03-17T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 200,
#     "Category": "WORLD GEOGRAPHY",
#     "Question": "The Republic of China is also known by this name, which is that of its main island",
#     "Answer": "Taiwan"
#   },
#   {
#     "AirDate": "1999-10-11T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 200,
#     "Category": "RELIGION",
#     "Question": "Legend says he spent 98 days beneath a large bo tree, 49 to solve the riddle of suffering & 49 more to meditate",
#     "Answer": "Buddha"
#   },
#   {
#     "AirDate": "1989-12-26T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 800,
#     "Category": "ISLANDS",
#     "Question": "A large \"bounty\" to the residents of this island is the money they receive from the sale of stamps",
#     "Answer": "Pitcairn Island"
#   },
#   {
#     "AirDate": "2009-03-25T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 400,
#     "Category": "BEFORE & AFTER",
#     "Question": "Star of 2008's \"Incredible Hulk\" who is a software program that gives spyware protection",
#     "Answer": "Edward Norton Anti-Virus"
#   },
#   {
#     "AirDate": "2000-02-18T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 300,
#     "Category": "BEFORE & AFTER",
#     "Question": "\"The Bone Collector\" star who penned \"Rip Van Winkle\"",
#     "Answer": "Denzel Washington Irving"
#   },
#   {
#     "AirDate": "2004-12-27T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 2200,
#     "Category": "SCIENCE",
#     "Question": "This amino acid is the sodium salt of glutamic acid",
#     "Answer": "monosodium glutamate (or MSG)"
#   },
#   {
#     "AirDate": "2001-05-25T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 100,
#     "Category": "SCIENCE & NATURE",
#     "Question": "About one-millionth as bright as our sun, these small red stars are also known as flare stars",
#     "Answer": "dwarfs"
#   },
#   {
#     "AirDate": "2004-07-19T00:00:00+00:00",
#     "Round": "Final Jeopardy!",
#     "Points": 0,
#     "Category": "OPERA",
#     "Question": "The libretto for \"William Tell\" was in this language, the native tongue of neither the composer, Rossini, nor the subject",
#     "Answer": "French"
#   },
#   {
#     "AirDate": "1998-04-15T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 200,
#     "Category": "COMMON BONDS",
#     "Question": "Spy, hour, stained",
#     "Answer": "glass"
#   },
#   {
#     "AirDate": "1990-02-19T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 100,
#     "Category": "FOOD",
#     "Question": "Often served over asparagus, this creamy sauce was 1st made in France, not in the Netherlands",
#     "Answer": "Hollandaise sauce"
#   },
#   {
#     "AirDate": "1997-07-15T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 200,
#     "Category": "LITERATURE",
#     "Question": "In 1922 he published \"The Red House Mystery\"; in 1928 \"The House At Pooh Corner\"",
#     "Answer": "A.A. Milne"
#   },
#   {
#     "AirDate": "2000-07-04T00:00:00+00:00",
#     "Round": "Final Jeopardy!",
#     "Points": 0,
#     "Category": "U.S. HISTORY",
#     "Question": "In 1965 President Johnson flew to this state to sign the Medicare bill with a former president as witness",
#     "Answer": "Missouri"
#   },
#   {
#     "AirDate": "1999-11-29T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 1000,
#     "Category": "WORD ORIGINS",
#     "Question": "Dervied from Old French for \"crane's foot\", it's a genealogical chart or family tree",
#     "Answer": "Pedigree"
#   },
#   {
#     "AirDate": "2004-09-14T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 1600,
#     "Category": "RHYME TIME",
#     "Question": "Nickname of Irwin Allen, who produced \"The Towering Inferno\" & \"The Poseidon Adventure\"",
#     "Answer": "the Master of Disaster"
#   },
#   {
#     "AirDate": "2004-10-22T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 400,
#     "Category": "STATE CAPITALS",
#     "Question": "More than half of all U.S. coins are made at the mint in this \"Mile High City\"",
#     "Answer": "Denver"
#   },
#   {
#     "AirDate": "1991-11-06T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 800,
#     "Category": "BOOKS & AUTHORS",
#     "Question": "Pulitzer Prize-winning playwright who wrote the novel \"The Human Comedy\"",
#     "Answer": "William Saroyan"
#   },
#   {
#     "AirDate": "1989-09-08T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 300,
#     "Category": "OPERA",
#     "Question": "Both of these opera companies are based at Lincoln Center",
#     "Answer": "Metropolitan & New York City Opera"
#   },
#   {
#     "AirDate": "2002-10-23T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 400,
#     "Category": "WORD ORIGINS",
#     "Question": "This nation's name is an acronym partly standing for Punjab, Afghan, Kashmir, Sind & \"Tan\" from Baluchistan",
#     "Answer": "Pakistan"
#   },
#   {
#     "AirDate": "1988-11-18T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 1000,
#     "Category": "STATE CAPITALS",
#     "Question": "It's the only one-word capital that has the name of its state contained within it",
#     "Answer": "Indianapolis"
#   },
#   {
#     "AirDate": "1999-02-05T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 600,
#     "Category": "SPORTS",
#     "Question": "In 1998 Mike Piazza set a short-lived record in this category:  7 years, 91 million",
#     "Answer": "Salary"
#   },
#   {
#     "AirDate": "1997-06-23T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 400,
#     "Category": "THE BIBLE",
#     "Question": "Of her twin boys, Rebekah favored this one",
#     "Answer": "Jacob"
#   },
#   {
#     "AirDate": "2008-03-24T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 1600,
#     "Category": "LANGUAGES",
#     "Question": "In the 1920s this language of Anatolia switched from the Arabic to the Latin alphabet",
#     "Answer": "Turkish"
#   },
#   {
#     "AirDate": "1997-02-14T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 400,
#     "Category": "TRANSPORTATION",
#     "Question": "In the 19th century Gustavus Swift developed this type of railway car to preserve his packed meat",
#     "Answer": "Refrigerator Car"
#   },
#   {
#     "AirDate": "1993-11-26T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 1000,
#     "Category": "STATE CAPITALS",
#     "Question": "This capital in the west is the site of Willamette University",
#     "Answer": "Salem, Oregon"
#   },
#   {
#     "AirDate": "2001-10-24T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 1200,
#     "Category": "BUSINESS & INDUSTRY",
#     "Question": "Entrepreneurs William Russell, Alexander Majors & William B. Waddell founded this in 1860; it lasted 18 months",
#     "Answer": "the Pony Express"
#   },
#   {
#     "AirDate": "1997-06-25T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 200,
#     "Category": "BALLET",
#     "Question": "This duke of jazz composed an original score for Alvin Ailey's brilliant modern ballet \"The River\"",
#     "Answer": "Duke Ellington"
#   },
#   {
#     "AirDate": "2006-10-09T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 400,
#     "Category": "STUPID ANSWERS",
#     "Question": "Sparkling wine sold under the name Champagne must come from this region in Northeast France",
#     "Answer": "Champagne"
#   },
#   {
#     "AirDate": "1999-01-29T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 500,
#     "Category": "ART & ARTISTS",
#     "Question": "The Prado boasts a fine portrait of 18th century artist Francisco Bayeu by this Spaniard, his brother-in-law",
#     "Answer": "Francisco Goya"
#   },
#   {
#     "AirDate": "1997-11-26T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 200,
#     "Category": "FICTIONAL CHARACTERS",
#     "Question": "Mickey Spillane's 1996 novel \"Black Alley\" is the first to feature this detective in 7 years",
#     "Answer": "Mike Hammer"
#   },
#   {
#     "AirDate": "1996-07-16T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 400,
#     "Category": "SHAKESPEARE",
#     "Question": "Her dying words are \"O Antony, nay I will take thee to;  what, should I stay?\"",
#     "Answer": "Cleopatra"
#   },
#   {
#     "AirDate": "2004-01-15T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 800,
#     "Category": "STUPID ANSWERS",
#     "Question": "David James Elliott of \"JAG\" might know it's the monogram of our 20th president",
#     "Answer": "JAG (James A. Garfield)"
#   },
#   {
#     "AirDate": "2011-06-29T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 800,
#     "Category": "LITERATURE",
#     "Question": "An 1894 Anthony Hope romance was titled this \"of Zenda\"",
#     "Answer": "the Prisoner"
#   },
#   {
#     "AirDate": "1986-02-10T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 1000,
#     "Category": "SHAKESPEARE",
#     "Question": "Falstaff was said to have \"eaten\" a widow \"out of\" this",
#     "Answer": "house and home"
#   },
#   {
#     "AirDate": "2003-05-29T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 1200,
#     "Category": "BUSINESS & INDUSTRY",
#     "Question": "This Freeport, Maine retail outlet's first product was the Maine Hunting Shoe, first sold in 1912",
#     "Answer": "L.L. Bean"
#   },
#   {
#     "AirDate": "1991-04-08T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 200,
#     "Category": "SHAKESPEARE",
#     "Question": "Cobweb is a fairy, not a spider, in this comedy",
#     "Answer": "A Midsummer Night's Dream"
#   },
#   {
#     "AirDate": "1989-01-03T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 500,
#     "Category": "RHYME TIME",
#     "Question": "An enthusiastic promoter of chanticleers",
#     "Answer": "a rooster booster"
#   },
#   {
#     "AirDate": "2007-07-25T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 1500,
#     "Category": "U.S. HISTORY",
#     "Question": "Seen <a href=\"http://www.j-archive.com/media/2007-07-25_J_18.jpg\" target=\"_blank\">here</a>, he was the earliest president ever to be photographed, & the first to have a middle name",
#     "Answer": "John Quincy Adams"
#   },
#   {
#     "AirDate": "1997-02-28T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 400,
#     "Category": "SPORTS",
#     "Question": "At the 1994 Olympics, this U.S. woman speed skater surpassed Eric Heiden's medal total",
#     "Answer": "Bonnie Blair"
#   },
#   {
#     "AirDate": "1995-07-06T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 300,
#     "Category": "SPORTS",
#     "Question": "With a capacity of just 38,756, this Chicago Cubs stadium is the smallest in the National League",
#     "Answer": "Wrigley Field"
#   },
#   {
#     "AirDate": "2000-06-09T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 200,
#     "Category": "AMERICAN HISTORY",
#     "Question": "2 forts were founded in Idaho in 1834: Fort Hall & this one that bore the name of the future capital",
#     "Answer": "Fort Boise"
#   },
#   {
#     "AirDate": "1988-07-05T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 300,
#     "Category": "WORLD HISTORY",
#     "Question": "The 1867 British North America Act united 3 colonies under this single name",
#     "Answer": "Canada"
#   },
#   {
#     "AirDate": "1998-05-27T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 800,
#     "Category": "FICTIONAL CHARACTERS",
#     "Question": "Last name of Soames & Irene, the 2 principal characters in John Galsworthy's 3 novel \"saga\"",
#     "Answer": "Forsyte"
#   },
#   {
#     "AirDate": "1984-11-28T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 800,
#     "Category": "U.S. HISTORY",
#     "Question": "It was his partner, James Marshall, who actually discovered gold at his California mill in 1849",
#     "Answer": "Sutter"
#   },
#   {
#     "AirDate": "1997-12-05T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 300,
#     "Category": "LITERATURE",
#     "Question": "Tom Canty, born in a slum called Offal Court, & Edward Tudor are the title characters in this Twain novel",
#     "Answer": "\"The Prince and the Pauper\""
#   },
#   {
#     "AirDate": "2005-09-26T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 800,
#     "Category": "WORD ORIGINS",
#     "Question": "From the Latin for \"mother\", it's a female prison worker who may be less than maternal",
#     "Answer": "matron"
#   },
#   {
#     "AirDate": "2000-06-30T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 500,
#     "Category": "BODIES OF WATER",
#     "Question": "Some say the Weddell Sea is an arm of the Antarctic Ocean; others say it's part of this larger ocean",
#     "Answer": "Atlantic Ocean"
#   },
#   {
#     "AirDate": "1998-09-17T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 1000,
#     "Category": "LITERATURE",
#     "Question": "Though not in travel brochures, Erskine Caldwell's \"Tobacco Road\" is located in this state",
#     "Answer": "Georgia"
#   },
#   {
#     "AirDate": "1997-05-06T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 600,
#     "Category": "WORLD GEOGRAPHY",
#     "Question": "Bhopal is the capital of this country's Madhya Pradesh state",
#     "Answer": "India"
#   },
#   {
#     "AirDate": "1990-11-15T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 200,
#     "Category": "OPERA",
#     "Question": "In \"Siegfried\" Fafner the giant is turned into one of these mythical beasts before Siegfried slays him",
#     "Answer": "a dragon"
#   },
#   {
#     "AirDate": "1995-07-07T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 300,
#     "Category": "AMERICANA",
#     "Question": "This U.S. first lady once taught dance in Grand Rapids",
#     "Answer": "Betty Ford"
#   },
#   {
#     "AirDate": "2003-07-07T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 800,
#     "Category": "POTPOURRI",
#     "Question": "It's what the \"Z\" stands for in zip code",
#     "Answer": "Zone (Zone Improvement Program)"
#   },
#   {
#     "AirDate": "2001-12-13T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 800,
#     "Category": "THE BIBLE",
#     "Question": "St. Paul attended a conference in Jerusalem to decide if this \"cutting\" practice was required",
#     "Answer": "circumcision"
#   },
#   {
#     "AirDate": "2004-03-04T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 400,
#     "Category": "SCIENCE & NATURE",
#     "Question": "A grub is this soft, thick stage of metamorphosis of flies, wasps & beetles",
#     "Answer": "larva"
#   },
#   {
#     "AirDate": "2000-12-14T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 300,
#     "Category": "U.S. HISTORY",
#     "Question": "In 1972 the \"T\" in the newsmaking SALT stood for this, not \"treaty\"",
#     "Answer": "Strategic Arms Limitation Talks"
#   },
#   {
#     "AirDate": "2002-09-26T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 400,
#     "Category": "BEFORE & AFTER",
#     "Question": "The Wicked Witch of the West's skywritten demand of the 1976 ladies' Olympic figure skating champion",
#     "Answer": "Surrender, Dorothy Hamill!"
#   },
#   {
#     "AirDate": "1992-09-28T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 1000,
#     "Category": "LANGUAGES",
#     "Question": "Zulu & Swahili are among the best-known languages of this African language group",
#     "Answer": "Bantu"
#   },
#   {
#     "AirDate": "1988-11-18T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 200,
#     "Category": "ART",
#     "Question": "The starting point and center of early Renaissance art was in this Italian city",
#     "Answer": "Florence"
#   },
#   {
#     "AirDate": "2003-02-10T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 800,
#     "Category": "SCIENCE & NATURE",
#     "Question": "The black-footed penguin is native to the south of this continent, whose north had the highest temperature on record",
#     "Answer": "Africa"
#   },
#   {
#     "AirDate": "2007-10-16T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 1500,
#     "Category": "COLLEGES & UNIVERSITIES",
#     "Question": "An anthem says, \"With each pealing bell... hail, all hail\" this New York university (it rhymes)",
#     "Answer": "Cornell"
#   },
#   {
#     "AirDate": "1990-11-15T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 800,
#     "Category": "WORLD GEOGRAPHY",
#     "Question": "This sea in the North Atlantic is delineated only by the plants that float on its surface",
#     "Answer": "the Sargasso Sea"
#   },
#   {
#     "AirDate": "2011-01-03T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 1200,
#     "Category": "THE BIBLE",
#     "Question": "In Matthew this ruler called for the deaths of all infant boys in Bethlehem: that's not so \"great\"",
#     "Answer": "Herod"
#   },
#   {
#     "AirDate": "1997-07-17T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 200,
#     "Category": "ART & ARTISTS",
#     "Question": "For one of his works, Marcel Duchamp added a beard & mustache to a print of this da Vinci lady",
#     "Answer": "Mona Lisa"
#   },
#   {
#     "AirDate": "2010-11-30T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 2000,
#     "Category": "OPERA",
#     "Question": "Bellini title gal who's high priestess of a Druid temple in Gaul",
#     "Answer": "Norma"
#   },
#   {
#     "AirDate": "1997-02-20T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 100,
#     "Category": "U.S. HISTORY",
#     "Question": "In 1981, just minutes after President Reagan was sworn in, the 52 hostages in this country were released",
#     "Answer": "Iran"
#   },
#   {
#     "AirDate": "2007-05-18T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 800,
#     "Category": "WORLD HISTORY",
#     "Question": "In 1606, Willem Janszoon landed on Cape York Peninsula, becoming the 1st European to visit this continent",
#     "Answer": "Australia"
#   },
#   {
#     "AirDate": "1999-05-27T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 200,
#     "Category": "WORLD HISTORY",
#     "Question": "Ferdinand & Isabella promised to make him \"Admiral of the Ocean Sea\" if he was successful in his 1492 voyage",
#     "Answer": "Christopher Columbus"
#   },
#   {
#     "AirDate": "1995-11-07T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 2000,
#     "Category": "BOOKS & AUTHORS",
#     "Question": "\"Terms of Endearment\" was his sixth novel with a Texas setting",
#     "Answer": "[Larry] McMurtry"
#   },
#   {
#     "AirDate": "2006-03-24T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 400,
#     "Category": "LITERATURE",
#     "Question": "In the 1600s Basho wrote a famous hard-to-translate haiku about this creature jumping into a pond",
#     "Answer": "a frog"
#   },
#   {
#     "AirDate": "1997-07-08T00:00:00+00:00",
#     "Round": "Final Jeopardy!",
#     "Points": 0,
#     "Category": "WORD ORIGINS",
#     "Question": "This word meaning an expert commentator is derived from the Sanskrit for \"learned man\"",
#     "Answer": "Pundit"
#   },
#   {
#     "AirDate": "1993-07-09T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 400,
#     "Category": "HISTORY",
#     "Question": "On his 1977 visit to Jerusalem, this Egyptian president prayed at the al-Aqsa mosque",
#     "Answer": "Anwar Sadat"
#   },
#   {
#     "AirDate": "2007-09-18T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 2000,
#     "Category": "WORLD CAPITALS",
#     "Question": "This city on the Malay Peninsula is the capital of Malaysia",
#     "Answer": "Kuala Lumpur"
#   },
#   {
#     "AirDate": "1994-11-21T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 400,
#     "Category": "ART",
#     "Question": "The floor type of this art form originated with pebble floors laid in late-Neolithic Crete",
#     "Answer": "Mosaics"
#   },
#   {
#     "AirDate": "2010-03-29T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 800,
#     "Category": "STUPID ANSWERS",
#     "Question": "(<a href=\"http://www.j-archive.com/media/2010-03-29_DJ_22.jpg\" target=\"_blank\">Sarah of the Clue Crew holds up some dolls at FAO Schwarz in New York.</a>)  Though beauty is in the eye of the beholder, some of these ugly dolls have three eyes, some have fangs, & some have big ears",
#     "Answer": "Uglydolls"
#   },
#   {
#     "AirDate": "2004-07-22T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 800,
#     "Category": "POTPOURRI",
#     "Question": "His frenzied female devotees were called maenads, or, from his other name, Bacchus, bacchantes",
#     "Answer": "Dionysus"
#   },
#   {
#     "AirDate": "2003-03-19T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 400,
#     "Category": "SPORTS",
#     "Question": "(I'm Hall of Fame running back Tony Dorsett)  This man was my coach for my first 11 seasons in the NFL",
#     "Answer": "Tom Landry"
#   },
#   {
#     "AirDate": "2007-10-08T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 2000,
#     "Category": "BODIES OF WATER",
#     "Question": "This largest lake in the Swiss Alps is actually a wide spot in the Rhone River",
#     "Answer": "Lake Geneva"
#   },
#   {
#     "AirDate": "1989-09-12T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 1100,
#     "Category": "LANGUAGES",
#     "Question": "At his 1969 investiture at Caernarvon Castle, Prince Charles spoke these 2 languages",
#     "Answer": "English & Welsh"
#   },
#   {
#     "AirDate": "2007-06-27T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 2000,
#     "Category": "WORLD CAPITALS",
#     "Question": "The name of this judicial capital of South Africa means \"Fountain of Flowers\"",
#     "Answer": "Bloemfontein"
#   },
#   {
#     "AirDate": "1996-01-30T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 200,
#     "Category": "POTPOURRI",
#     "Question": "Navigational instruments are displayed at the Maritime Museum near Franklin Court in this Penn. city",
#     "Answer": "Philadelphia"
#   },
#   {
#     "AirDate": "1996-11-20T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 800,
#     "Category": "SHAKESPEARE",
#     "Question": "When Benedict says \"Come, bid me do anything for thee\", she says \"Much ado - kill Claudio\"",
#     "Answer": "Beatrice"
#   },
#   {
#     "AirDate": "1997-12-05T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 500,
#     "Category": "LITERATURE",
#     "Question": "Leora, the wife of this Sinclair Lewis doctor, dies of bubonic plague on the island of St. Hubert",
#     "Answer": "Arrowsmith"
#   },
#   {
#     "AirDate": "2005-03-31T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 400,
#     "Category": "U.S. GEOGRAPHY",
#     "Question": "The Salt Lake Valley was once a part of the basin of this ancient lake",
#     "Answer": "Lake Bonneville"
#   },
#   {
#     "AirDate": "1996-12-12T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 600,
#     "Category": "SPORTS",
#     "Question": "Technically, this NFL team is located in Orchard Park, New York",
#     "Answer": "Buffalo Bills"
#   },
#   {
#     "AirDate": "2010-07-15T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 2000,
#     "Category": "SCIENCE & NATURE",
#     "Question": "Mosquitoes of this genus are the only ones that carry malaria",
#     "Answer": "the Anopheles mosquito"
#   },
#   {
#     "AirDate": "2002-11-22T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 1600,
#     "Category": "COLLEGES & UNIVERSITIES",
#     "Question": "This university's original building, erected in Elko in 1874, became a hospital for indigents before it was leveled in 1920",
#     "Answer": "University of Nevada"
#   },
#   {
#     "AirDate": "1998-07-16T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 300,
#     "Category": "SPORTS",
#     "Question": "Babe Ruth's father once operated a saloon on what is now center field in this Baltimore ballpark",
#     "Answer": "Oriole Park at Camden Yards"
#   },
#   {
#     "AirDate": "2009-05-11T00:00:00+00:00",
#     "Round": "Final Jeopardy!",
#     "Points": 0,
#     "Category": "WORD ORIGINS",
#     "Question": "Before its use in journalism, it meant a boundary beyond which straying prisoners would be shot",
#     "Answer": "deadline"
#   },
#   {
#     "AirDate": "2008-11-21T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 800,
#     "Category": "BODIES OF WATER",
#     "Question": "This Asian \"sea\" is actually a lake that's more than 4 1/2 times larger than Lake Superior",
#     "Answer": "the Caspian Sea"
#   },
#   {
#     "AirDate": "2002-12-13T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 400,
#     "Category": "OPERA",
#     "Question": "\"The Marriage of\" this servant of Count Almaviva was once banned in France lest it incite the lower classes to revolt",
#     "Answer": "Figaro"
#   },
#   {
#     "AirDate": "2005-05-05T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 2000,
#     "Category": "BALLET",
#     "Question": "1977's \"Calcium Light Night\" was the first ballet choreographed by this great Dane, Ballet Master in Chief of the NYCB",
#     "Answer": "Peter Martins"
#   },
#   {
#     "AirDate": "1997-07-15T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 200,
#     "Category": "WORLD GEOGRAPHY",
#     "Question": "Important mining centers in this range include Leadville, Colorado & Kimberley, British Columbia",
#     "Answer": "Rocky Mountains"
#   },
#   {
#     "AirDate": "1996-11-21T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 200,
#     "Category": "TRANSPORTATION",
#     "Question": "From Port Said to Al-Qantara, this canal passes through Lake Manzala, a lagoon",
#     "Answer": "the Suez Canal"
#   },
#   {
#     "AirDate": "2001-03-02T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 200,
#     "Category": "STUPID ANSWERS",
#     "Question": "On 7/11/2000 this company announced the opening of its 20,000th store, a new one in Tokyo",
#     "Answer": "7-Eleven"
#   },
#   {
#     "AirDate": "1998-01-07T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 100,
#     "Category": "ISLANDS",
#     "Question": "The Danes call this island dependency in the north Atlantic Gronland",
#     "Answer": "Greenland"
#   },
#   {
#     "AirDate": "2000-06-13T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 400,
#     "Category": "PEOPLE",
#     "Question": "(Hi, I'm Patrika Darbo of \"Days of our Lives\")  In a 1994 TV movie I played this domestic goddess comedienne turned sitcom star",
#     "Answer": "Roseanne"
#   },
#   {
#     "AirDate": "2000-12-08T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 200,
#     "Category": "RHYME TIME",
#     "Question": "The purple Teletubby",
#     "Answer": "Tinky Winky"
#   },
#   {
#     "AirDate": "2005-01-05T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 800,
#     "Category": "AMERICANA",
#     "Question": "At the Cabildo in New Orleans, you can see the death mask of this ruler who ceded New Orleans to the U.S.",
#     "Answer": "Napoleon (I)"
#   },
#   {
#     "AirDate": "1997-06-25T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 400,
#     "Category": "TELEVISION",
#     "Question": "In 1996 he won the first acting Emmy for a cable TV series for playing Artie on \"The Larry Sanders Show\"",
#     "Answer": "Rip Torn"
#   },
#   {
#     "AirDate": "2002-10-31T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 800,
#     "Category": "SCIENCE & NATURE",
#     "Question": "The Puerto Rico Trench has the Atlantic's deepest point; this trench has the Pacific's",
#     "Answer": "Marianas Trench"
#   },
#   {
#     "AirDate": "2001-07-16T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 1000,
#     "Category": "TRANSPORTATION",
#     "Question": "One of these in Wuppertal, Germany has been operating since 1901, the year Walt Disney was born",
#     "Answer": "monorail"
#   },
#   {
#     "AirDate": "2003-11-10T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 1000,
#     "Category": "SCIENCE & NATURE",
#     "Question": "This property is the reason a rubber ball bounces & a stretched rubber band springs back to size",
#     "Answer": "elasticity"
#   },
#   {
#     "AirDate": "2000-04-10T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 1000,
#     "Category": "SCIENCE",
#     "Question": "Abbreviated lm, it's a measurement of light",
#     "Answer": "Lumen"
#   },
#   {
#     "AirDate": "2004-05-24T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 200,
#     "Category": "SCIENCE & NATURE",
#     "Question": "In 1997 the world said \"Hello Dolly\" to one of these mammals, the first successfully cloned",
#     "Answer": "a sheep"
#   },
#   {
#     "AirDate": "1997-09-16T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 600,
#     "Category": "HISTORY",
#     "Question": "England's first encounter with this fleet occurred off Plymouth July 31, 1588",
#     "Answer": "The Spanish Armada"
#   },
#   {
#     "AirDate": "2003-03-19T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 1000,
#     "Category": "LANGUAGES",
#     "Question": "Gaspar Karolyi's translation of the Bible in 1590 was influential in the development of this as a national language",
#     "Answer": "Hungarian"
#   },
#   {
#     "AirDate": "2001-02-22T00:00:00+00:00",
#     "Round": "Final Jeopardy!",
#     "Points": 0,
#     "Category": "WORD ORIGINS",
#     "Question": "Ironically, this synonym for a stupid person is based on the name of 1 of the most brilliant scholars of the 14th c.",
#     "Answer": "Dunce (from John Duns Scotus)"
#   },
#   {
#     "AirDate": "1996-04-15T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 400,
#     "Category": "WORD ORIGINS",
#     "Question": "This word for a ceremonial procession is from old Italian cavalcare, \"to ride on horseback\"",
#     "Answer": "Cavalcade"
#   },
#   {
#     "AirDate": "2008-04-28T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 400,
#     "Category": "LANGUAGES",
#     "Question": "Related to Italian, it has about 5 million speakers in S. Italy & on a large Mediterranean island",
#     "Answer": "Sicilian"
#   },
#   {
#     "AirDate": "2009-12-23T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 800,
#     "Category": "BEFORE & AFTER",
#     "Question": "Woody Allen romantic comedy about a student who patrols the corridors of a school",
#     "Answer": "Annie Hall Monitor"
#   },
#   {
#     "AirDate": "1987-11-20T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 200,
#     "Category": "RELIGION",
#     "Question": "The president of this Arab country must be a Maronite Christian",
#     "Answer": "Lebanon"
#   },
#   {
#     "AirDate": "1997-03-12T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 1000,
#     "Category": "ANIMALS",
#     "Question": "Scientists divide these toothless whales into 3 groups: right whales, gray whales & rorquals",
#     "Answer": "Baleen whales"
#   },
#   {
#     "AirDate": "1999-11-30T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 400,
#     "Category": "SHAKESPEARE",
#     "Question": "This mischievous trickster delivers the epilogue to \"A Midsummer Night's Dream\"",
#     "Answer": "Puck"
#   },
#   {
#     "AirDate": "1990-04-02T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 400,
#     "Category": "FICTIONAL CHARACTERS",
#     "Question": "John D. MacDonald used colors in the titles of all the adventures of this private investigator",
#     "Answer": "Travis McGee"
#   },
#   {
#     "AirDate": "1998-10-12T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 700,
#     "Category": "TELEVISION",
#     "Question": "(VIDEO DAILY DOUBLE): \"(Hi, I'm Fred Savage): In an episode of \"Working\", I pick up Danica McKellar, who played this \"Wonder Years\" character\"",
#     "Answer": "Winnie Cooper"
#   },
#   {
#     "AirDate": "1996-01-24T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 400,
#     "Category": "SCIENCE",
#     "Question": "2 bacteria, Lactobacillus Bulgaricus & Streptococcus Thermophilus, turn milk into this",
#     "Answer": "Yogurt"
#   },
#   {
#     "AirDate": "1992-11-11T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 400,
#     "Category": "SHAKESPEARE",
#     "Question": "This \"Merchant of Venice\" heiress has many suitors, including the Duke of Saxony's nephew",
#     "Answer": "Portia"
#   },
#   {
#     "AirDate": "1989-01-03T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 200,
#     "Category": "RHYME TIME",
#     "Question": "An order to put shaving cream all over the face of CBS news anchor Dan",
#     "Answer": "lather Rather"
#   },
#   {
#     "AirDate": "1987-11-20T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 400,
#     "Category": "RELIGION",
#     "Question": "At first, Jim Bakker claimed that this Louisiana-based Pentecostal preacher wanted to take over the PTL",
#     "Answer": "Jimmy Swaggart"
#   },
#   {
#     "AirDate": "1989-01-03T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 1000,
#     "Category": "PEOPLE",
#     "Question": "A goddaughter of the Duke & Duchess of Windsor, this debutante used to date Sly Stallone",
#     "Answer": "Cornelia Guest"
#   },
#   {
#     "AirDate": "2006-12-14T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 400,
#     "Category": "ANIMALS",
#     "Question": "(<a href=\"http://www.j-archive.com/media/2006-12-14_J_07.jpg\" target=\"_blank\">Jimmy of the Clue Crew poses next to a cow at Old World, Wisconsin.</a>)  This is the name of a cow that is less than 3 years old that hasn't given birth; Zeus turned Io into a white one",
#     "Answer": "a heifer"
#   },
#   {
#     "AirDate": "2008-01-03T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 2000,
#     "Category": "LITERATURE",
#     "Question": "The title of this Steinbeck novel refers to a district above Monterey inhabited by Paisanos",
#     "Answer": "Tortilla Flat"
#   },
#   {
#     "AirDate": "2004-09-24T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 2000,
#     "Category": "AMERICANA",
#     "Question": "In 1986 this model kit company merged with its main competitor, Monogram",
#     "Answer": "Revell"
#   },
#   {
#     "AirDate": "1997-05-29T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 100,
#     "Category": "ART",
#     "Question": "The artists known as The Four Wangs rose to prominence under this country's Ch'ing Dynasty",
#     "Answer": "China"
#   },
#   {
#     "AirDate": "1992-09-28T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 200,
#     "Category": "SCIENCE",
#     "Question": "This is the name of our own galaxy",
#     "Answer": "the Milky Way"
#   },
#   {
#     "AirDate": "1997-03-19T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 1000,
#     "Category": "AMERICAN HISTORY",
#     "Question": "On September 14, 1847, this general led the American army into Mexico City",
#     "Answer": "Winfield Scott"
#   },
#   {
#     "AirDate": "1989-11-10T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 100,
#     "Category": "SCIENCE",
#     "Question": "The mother of a mule",
#     "Answer": "Horse (Mare)"
#   },
#   {
#     "AirDate": "1997-12-24T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 300,
#     "Category": "TELEVISION",
#     "Question": "MTV's 1997 spin-off \"Daria\" features a character from this moronic animated series",
#     "Answer": "Beavis and Butt-Head"
#   },
#   {
#     "AirDate": "2009-05-29T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 400,
#     "Category": "SCIENCE",
#     "Question": "Isaac Newton published his first mathematical formulation for this fundamental force in 1687",
#     "Answer": "gravity"
#   },
#   {
#     "AirDate": "2003-06-30T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 800,
#     "Category": "HISTORY",
#     "Question": "A tsar from age 16, during his despotic reign Russia got its first printing press in 1563",
#     "Answer": "Ivan the Terrible"
#   },
#   {
#     "AirDate": "1995-11-21T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 400,
#     "Category": "MUSEUMS",
#     "Question": "This Dutch national art museum had its origins in one founded by Louis Bonaparte in 1808",
#     "Answer": "The Rijksmuseum"
#   },
#   {
#     "AirDate": "2006-07-21T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 1200,
#     "Category": "U.S. CITIES",
#     "Question": "Billy Joel could tell you this \"town\" near Bethlehem, Penn. has the oldest municipal band in the U.S.",
#     "Answer": "Allentown"
#   },
#   {
#     "AirDate": "2001-10-22T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 400,
#     "Category": "LITERATURE",
#     "Question": "In \"Pudd'nhead Wilson\", Twain wrote, \"Put all your eggs in the one basket and\" then do this to \"that basket\"",
#     "Answer": "watch"
#   },
#   {
#     "AirDate": "1990-05-22T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 600,
#     "Category": "MUSEUMS",
#     "Question": "This island, famous for its coffee beans, is the home of the Royal Kona Coffee Mill & Museum",
#     "Answer": "Big Island of Hawaii"
#   },
#   {
#     "AirDate": "1996-11-22T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 400,
#     "Category": "BOOKS & AUTHORS",
# ...
#     "Answer": "Bella Abzug"
#   },
#   {
#     "AirDate": "1998-04-15T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 400,
#     "Category": "COMMON BONDS",
#     "Question": "Bachelor's, panic, belly",
#     "Answer": "button"
#   },
#   {
#     "AirDate": "1989-11-09T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 600,
#     "Category": "LANGUAGES",
#     "Question": "This is the only European language where adjectives don't change to agree with the nouns they modify",
#     "Answer": "English"
#   },
#   {
#     "AirDate": "2004-03-15T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 1000,
#     "Category": "LITERATURE",
#     "Question": "In 1856 Revue de Paris readers followed this tale of the miserable wife of a boring doctor",
#     "Answer": "Madame Bovary"
#   },
#   {
#     "AirDate": "2007-12-17T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 1200,
#     "Category": "ART & ARTISTS",
#     "Question": "Maurice Utrillo often painted scenes of this area of Paris & its best-known landmark, Sacre Coeur",
#     "Answer": "Montmartre"
#   },
#   {
#     "AirDate": "1998-01-13T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 400,
#     "Category": "WORLD GEOGRAPHY",
#     "Question": "Libya's Gulf of Sidra is the southernmost point of this huge sea",
#     "Answer": "Mediterranean Sea"
#   },
#   {
#     "AirDate": "2003-01-23T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 1000,
#     "Category": "STUPID ANSWERS",
#     "Question": "Extra atoms of this element are pumped into unsaturated oil to make hydrogenated fat",
#     "Answer": "hydrogen"
#   },
#   {
#     "AirDate": "1996-09-05T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 800,
#     "Category": "U.S. GEOGRAPHY",
#     "Question": "Covering 625 square miles, it's Louisiana's largest lake",
#     "Answer": "Lake Pontchartrain"
#   },
#   {
#     "AirDate": "2002-11-22T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 400,
#     "Category": "COLLEGES & UNIVERSITIES",
#     "Question": "In 1795 in Chapel Hill the university of this state became the first U.S. state university to open its doors",
#     "Answer": "North Carolina"
#   },
#   {
#     "AirDate": "1997-11-03T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 800,
#     "Category": "U.S. CITIES",
#     "Question": "This state capital is home to the 4 1/2 acre Roger Williams National Memorial Park",
#     "Answer": "Providence, Rhode Island"
#   },
#   {
#     "AirDate": "1990-03-22T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 100,
#     "Category": "SPORTS",
#     "Question": "The first bobsled races were held in this mountainous country",
#     "Answer": "Switzerland"
#   },
#   {
#     "AirDate": "2000-05-30T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 100,
#     "Category": "TRANSPORTATION",
#     "Question": "On May 10, 1869 it became the first continent to have a rail line running from its east coast to its west coast",
#     "Answer": "North America"
#   },
#   {
#     "AirDate": "2008-12-02T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 8000,
#     "Category": "WORLD GEOGRAPHY",
#     "Question": "At the beginning of World War I, this was the only independent nation in West Africa",
#     "Answer": "Liberia"
#   },
#   {
#     "AirDate": "2008-09-15T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 1200,
#     "Category": "SPORTS",
#     "Question": "In 2008 this Spaniard defeated Roger Federer in the longest-ever final at Wimbledon",
#     "Answer": "Rafael Nadal"
#   },
#   {
#     "AirDate": "1997-04-17T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 800,
#     "Category": "ANIMALS",
#     "Question": "The Phoenicians used a liquid from several species of this gastropod to make Tyrian purple dye",
#     "Answer": "Snail"
#   },
#   {
#     "AirDate": "2006-03-24T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 6000,
#     "Category": "LITERATURE",
#     "Question": "After Christian's death in an 1897 drama, this title character still acts as a platonic friend to the widow",
#     "Answer": "Cyrano de Bergerac"
#   },
#   {
#     "AirDate": "1998-01-13T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 200,
#     "Category": "WORLD GEOGRAPHY",
#     "Question": "This country's Cancun resort lies on a barrier island once inhabited by Maya Indians",
#     "Answer": "Mexico"
#   },
#   {
#     "AirDate": "2001-07-10T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 800,
#     "Category": "OPERA",
#     "Question": "He was in his 70s when he composed \"Otello\" in 1887 & \"Falstaff\" in 1893",
#     "Answer": "Giuseppe Verdi"
#   },
#   {
#     "AirDate": "2003-02-12T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 200,
#     "Category": "ART & ARTISTS",
#     "Question": "Around 1850, you could find Eugene Delacroix painting the ceiling of this French museum's Salon d'Apollon",
#     "Answer": "the Louvre"
#   },
#   {
#     "AirDate": "1998-09-17T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 200,
#     "Category": "LITERATURE",
#     "Question": "The only thing this \"Wizard of Oz\" character was afraid of was \"a lighted match\"",
#     "Answer": "the Scarecrow"
#   },
#   {
#     "AirDate": "2003-04-22T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 400,
#     "Category": "BALLET",
#     "Question": "If the original play is too long for you, you might like \"The Dream\", a 1-act ballet based on this Shakespeare play",
#     "Answer": "A Midsummer Night's Dream"
#   },
#   {
#     "AirDate": "1996-12-30T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 200,
#     "Category": "TELEVISION",
#     "Question": "On this series, Sgt. Phil Esterhaus ended roll call with \"And, hey -- let's be careful out there\"",
#     "Answer": "\"Hill Street Blues\""
#   },
#   {
#     "AirDate": "1997-04-24T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 200,
#     "Category": "STATE CAPITALS",
#     "Question": "The area of this Wyoming capital was first occupied by the Native American tribe for which it's named",
#     "Answer": "Cheyenne"
#   },
#   {
#     "AirDate": "1989-09-12T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 200,
#     "Category": "LANGUAGES",
#     "Question": "Though Polish is a Slavic language, it uses this alphabet",
#     "Answer": "Latin (or Western)"
#   },
#   {
#     "AirDate": "1996-09-02T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 200,
#     "Category": "BODIES OF WATER",
#     "Question": "This South American river has more than a thousand known tributaries",
#     "Answer": "the Amazon"
#   },
#   {
#     "AirDate": "2003-10-15T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 1200,
#     "Category": "BOOKS & AUTHORS",
#     "Question": "In 2003 Spenser & Hawk returned in a novel called \"Back Story\" by this author",
#     "Answer": "Robert B. Parker"
#   },
#   {
#     "AirDate": "1997-10-09T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 200,
#     "Category": "STATE CAPITALS",
#     "Question": "This seat of Kent County, Delaware is named for a city in England's county of Kent",
#     "Answer": "Dover"
#   },
#   {
#     "AirDate": "2003-01-30T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 1200,
#     "Category": "HISTORY",
#     "Question": "In 1497 John Cabot visited the area of this Newfoundland capital & named it for a beheaded saint",
#     "Answer": "St. John's"
#   },
#   {
#     "AirDate": "2000-03-14T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 200,
#     "Category": "U.S. GEOGRAPHY",
#     "Question": "Of 8, 12 or 18, the number of U.S. states that touch the Atlantic Ocean",
#     "Answer": "18"
#   },
#   {
#     "AirDate": "1986-10-03T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 500,
#     "Category": "RELIGION",
#     "Question": "A hit in 1953, this song of faith made No. 3 on the charts when Elvis released in in 1965",
#     "Answer": "Crying in the Chapel"
#   },
#   {
#     "AirDate": "1984-12-04T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 200,
#     "Category": "FOOD",
#     "Question": "Type of food that comes in shapes of bow ties, elbows & wagon wheels",
#     "Answer": "pasta"
#   },
#   {
#     "AirDate": "1997-07-01T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 600,
#     "Category": "ANIMALS",
#     "Question": "The name of this large rodent is from the middle French for \"pig with spines\"",
#     "Answer": "Porcupine"
#   },
#   {
#     "AirDate": "1990-09-03T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 100,
#     "Category": "FOOD",
#     "Question": "When he returned to Venice from the Far East, he introduced the idea of fruit flavored ices",
#     "Answer": "Marco Polo"
#   },
#   {
#     "AirDate": "1997-05-09T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 200,
#     "Category": "TRANSPORTATION",
#     "Question": "Kanmon Tunnel, the world's first under an ocean, connects the island of Kyushu with this island",
#     "Answer": "Honshu"
#   },
#   {
#     "AirDate": "1997-05-29T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 200,
#     "Category": "WORLD GEOGRAPHY",
#     "Question": "Less than 5,000 square miles in area, The Gambia is the smallest independent mainland country on this continent",
#     "Answer": "Africa"
#   },
#   {
#     "AirDate": "1996-11-14T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 200,
#     "Category": "BODIES OF WATER",
#     "Question": "This largest ocean supplies about half of the world's yearly supply of fish & shellfish",
#     "Answer": "the Pacific Ocean"
#   },
#   {
#     "AirDate": "1997-01-10T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 200,
#     "Category": "AMERICAN HISTORY",
#     "Question": "This monument with a 19-foot seated statue was dedicated by President Harding May 30, 1922",
#     "Answer": "Lincoln Memorial"
#   },
#   {
#     "AirDate": "1995-11-07T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 600,
#     "Category": "BOOKS & AUTHORS",
#     "Question": "In 1961 the first American edition of his \"Tropic of Cancer\" became a bestseller",
#     "Answer": "[Henry] Miller"
#   },
#   {
#     "AirDate": "1994-11-17T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 400,
#     "Category": "U.S. GEOGRAPHY",
#     "Question": "Albuquerque, New Mexico lies on this 1885-mile long river",
#     "Answer": "the Rio Grande"
#   },
#   {
#     "AirDate": "2010-04-22T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 400,
#     "Category": "BEFORE & AFTER",
#     "Question": "'50s sitcom dad to Ricky & David who became president of South Africa in 1994",
#     "Answer": "Ozzie Nelson Mandela"
#   },
#   {
#     "AirDate": "1997-03-13T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 800,
#     "Category": "SCIENCE & NATURE",
#     "Question": "The order caudata consists of newts & these tailed amphibians, including mudpuppies",
#     "Answer": "Salamanders"
#   },
#   {
#     "AirDate": "2008-04-14T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 600,
#     "Category": "POTPOURRI",
#     "Question": "Its chemical symbol is Sn",
#     "Answer": "tin (stannous)"
#   },
#   {
#     "AirDate": "1992-11-12T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 100,
#     "Category": "ANIMALS",
#     "Question": "Like its giant relative, the lesser variety of this is also a bamboo eater",
#     "Answer": "Panda"
#   },
#   {
#     "AirDate": "2007-02-28T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 400,
#     "Category": "SCIENCE",
#     "Question": "The universe's background radiation is thought to be left over from this primordial event",
#     "Answer": "the Big Bang"
#   },
#   {
#     "AirDate": "1999-04-22T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 400,
#     "Category": "OPERA",
#     "Question": "Ferenc Erkel's 1844 work \"Hunyady Laszlo\" is one of this country's most famous operas",
#     "Answer": "Hungary"
#   },
#   {
#     "AirDate": "1997-05-27T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 400,
#     "Category": "ANIMALS",
#     "Question": "The \"black\" species of this large horned mammal can grasp twigs with its upper lip",
#     "Answer": "Rhinoceros"
#   },
#   {
#     "AirDate": "2000-02-21T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 300,
#     "Category": "BOOKS & AUTHORS",
#     "Question": "\"Welcome to the Monkey House\", \"Galapagos\", \"Player Piano\"",
#     "Answer": "Kurt Vonnegut"
#   },
#   {
#     "AirDate": "1996-01-16T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 1000,
#     "Category": "WORLD HISTORY",
#     "Question": "In 1968 Marcello Caetano replaced this longtime dictator as ruler of Portugal",
#     "Answer": "Antonio de Salazar"
#   },
#   {
#     "AirDate": "1997-06-24T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 1000,
#     "Category": "SCIENCE",
#     "Question": "The name of this dog star, the brightest star in the night sky, is Greek for \"scorching\"",
#     "Answer": "Sirius"
#   },
#   {
#     "AirDate": "2000-09-14T00:00:00+00:00",
#     "Round": "Final Jeopardy!",
#     "Points": 0,
#     "Category": "WORD ORIGINS",
#     "Question": "This residential district of Dublin held an annual fair from 1204 to 1855, when it was closed due to frequent fights",
#     "Answer": "Donnybrook"
#   },
#   {
#     "AirDate": "1992-10-27T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 800,
#     "Category": "STATE CAPITALS",
#     "Question": "This New Mexico capital was founded by Don Pedro de Peralta around 1610",
#     "Answer": "Santa Fe"
#   },
#   {
#     "AirDate": "2006-09-12T00:00:00+00:00",
#     "Round": "Final Jeopardy!",
#     "Points": 0,
#     "Category": "AMERICANA",
#     "Question": "In June 2005, amid some controversy, a statue of Elizabeth Montgomery was unveiled in this city",
#     "Answer": "Salem, Massachusetts"
#   },
#   {
#     "AirDate": "1998-12-10T00:00:00+00:00",
#     "Round": "Final Jeopardy!",
#     "Points": 0,
#     "Category": "ISLANDS",
#     "Question": "A species of mammal is named for this appropriate site of Russia's first American settlement",
#     "Answer": "Kodiak Island"
#   },
#   {
#     "AirDate": "2000-10-23T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 600,
#     "Category": "STATE CAPITALS",
#     "Question": "In 1999 the team once known as the Houston Oilers made a slick move to this capital",
#     "Answer": "Nashville (Tennessee Titans)"
#   },
#   {
#     "AirDate": "2007-02-14T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 800,
#     "Category": "BOOKS & AUTHORS",
#     "Question": "In Meg Cabot's \"Valentine Princess\", this girl's grandmere disapproves of her boyfriend Michael",
#     "Answer": "Princess Mia"
#   },
#   {
#     "AirDate": "1994-11-25T00:00:00+00:00",
#     "Round": "Jeopardy!",
#     "Points": 300,
#     "Category": "STATE CAPITALS",
#     "Question": "This Kansas city's zoological park boasts a tropical rain forest habitat",
#     "Answer": "Topeka"
#   },
#   {
#     "AirDate": "1996-12-12T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 200,
#     "Category": "SPORTS",
#     "Question": "This school's Cornhuskers won the 1995 college football title by overwhelming Florida in the Fiesta Bowl",
#     "Answer": "Nebraska"
#   },
#   {
#     "AirDate": "1996-04-09T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 400,
#     "Category": "FOOD",
#     "Question": "A wax bean is a variety of green bean that's this color",
#     "Answer": "Yellow"
#   },
#   {
#     "AirDate": "1999-11-16T00:00:00+00:00",
#     "Round": "Double Jeopardy!",
#     "Points": 400,
#     "Category": "POTPOURRI",
#     "Question": "(<a href=\"http://www.j-archive.com/media/1999-11-16_DJ_17.jpg\" target=\"_blank\">Hi, I'm Vanna White at Christian Dior in New York City.</a>)  This actress was wearing a Dior gown when she won her first Oscar for \"BUtterfield 8\"",
#     "Answer": "Elizabeth Taylor"
#   }
# ]
# /var/folders/3v/_jgc177x2ln06306pq8qlcqc0000gn/T/ipykernel_16934/4207601610.py:1: ResourceWarning: unclosed file <_io.TextIOWrapper name='./data/jeopardy_1k.json' mode='r' encoding='UTF-8'>
#   data_1k = json.load(open("./data/jeopardy_1k.json"))
# ResourceWarning: Enable tracemalloc to get the object allocation traceback

# %%
# Insert data
questions = client.collections.get("Questions")


with questions.batch.fixed_size(batch_size=100, concurrent_requests=2) as batch:
    for item in data_1k:
        batch.add_object({
            "Round": item["Round"],
            "Points": item["Points"],
            "Category": item["Category"],
            "Question": item["Question"],
            "Answer": item["Answer"]
        })

# %%
if(len(questions.batch.failed_objects)>0):
    print("Import complete with errors")
    for err in questions.batch.failed_objects:
        print(err)
else:
    print("Import complete with no errors")
# Out:
# Import complete with no errors
